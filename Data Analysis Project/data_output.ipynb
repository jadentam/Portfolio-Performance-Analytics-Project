# %%
## Running the Risk Metric Calculations
# %run risk_metric_calc.ipynb
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 1338 entries, 2021-01-04 to 2026-05-01
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   BUFR    1338 non-null   float64
#  1   IJR     1338 non-null   float64
#  2   SMH     1338 non-null   float64
#  3   SPY     1338 non-null   float64
#  4   UGL     1338 non-null   float64
#  5   VO      1338 non-null   float64
# dtypes: float64(6)
# memory usage: 73.2 KB

# %%
## Outputting a Plotted Diagram for the Value of Portfolio vs. Benchmark
plt.figure(figsize=(12, 6))
plt.plot(portfolio_returns.index, portfolio_returns["Portfolio_Value"], label="Portfolio")
plt.plot(portfolio_returns.index, portfolio_returns["Benchmark_Value"], label="Benchmark")
plt.title("Portfolio Value vs Benchmark Value")
plt.xlabel("Date")
plt.ylabel("Value")
plt.legend()
plt.show()

# %%
## Outputting the Drawdown Comparison between the Portfolio and the Benchmark
plt.figure(figsize=(12, 6))
plt.plot(portfolio_returns.index, portfolio_returns["Portfolio_Drawdown"], label="Portfolio Drawdown")
plt.plot(portfolio_returns.index, portfolio_returns["Benchmark_Drawdown"], label="Benchmark Drawdown")
plt.title("Drawdown Comparison")
plt.xlabel("Date")
plt.ylabel("Drawdown")
plt.legend()
plt.show()
